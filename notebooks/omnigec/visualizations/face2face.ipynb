# %%
import pandas as pd

data = [
    {"language": "Czech",      "corpus": "NatWebInf",    "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 68.12, "AYA-Expanse-8b (Inference Chunked)": 68.17, "AYA-Expanse-8B (OmniGEC)": 67.82, "Gemma-3-12B-IT (MultiGEC)": 56.31, "Gemma-3-12B-IT (OmniGEC)": 64.70, "LLaMA-3-8B (MultiGEC)": 65.06, "Gemma-2-9B (MultiGEC)": 69.89},
    {"language": "Czech",      "corpus": "Romani",       "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 55.89, "AYA-Expanse-8b (Inference Chunked)": 58.21, "AYA-Expanse-8B (OmniGEC)": 58.02, "Gemma-3-12B-IT (MultiGEC)": 51.70, "Gemma-3-12B-IT (OmniGEC)": 53.30, "LLaMA-3-8B (MultiGEC)": 53.70, "Gemma-2-9B (MultiGEC)": 60.07},
    {"language": "Czech",      "corpus": "SecLearn",     "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 53.69, "AYA-Expanse-8b (Inference Chunked)": 53.77, "AYA-Expanse-8B (OmniGEC)": 54.62, "Gemma-3-12B-IT (MultiGEC)": 50.07, "Gemma-3-12B-IT (OmniGEC)": 53.84, "LLaMA-3-8B (MultiGEC)": 49.95, "Gemma-2-9B (MultiGEC)": 55.81},
    {"language": "Czech",      "corpus": "NatForm",      "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 79.00, "AYA-Expanse-8b (Inference Chunked)": 80.09, "AYA-Expanse-8B (OmniGEC)": 80.07, "Gemma-3-12B-IT (MultiGEC)": 74.57, "Gemma-3-12B-IT (OmniGEC)": 77.45, "LLaMA-3-8B (MultiGEC)": 71.45, "Gemma-2-9B (MultiGEC)": 81.44},
    {"language": "English",    "corpus": "Write & Improve", "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 78.48, "AYA-Expanse-8b (Inference Chunked)": 78.45, "AYA-Expanse-8B (OmniGEC)": 78.08, "Gemma-3-12B-IT (MultiGEC)": 72.12, "Gemma-3-12B-IT (OmniGEC)": 76.62, "LLaMA-3-8B (MultiGEC)": 77.90, "Gemma-2-9B (MultiGEC)": 81.50},
    {"language": "Estonian",   "corpus": "EIC",         "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 33.27, "AYA-Expanse-8b (Inference Chunked)": 30.52, "AYA-Expanse-8B (OmniGEC)": 41.52, "Gemma-3-12B-IT (MultiGEC)": 54.74, "Gemma-3-12B-IT (OmniGEC)": 57.54, "LLaMA-3-8B (MultiGEC)": 44.02, "Gemma-2-9B (MultiGEC)": 55.76},
    {"language": "Estonian",   "corpus": "EIC",         "track": "fluency", "AYA-Expanse-8B (MultiGEC)": 35.66, "AYA-Expanse-8b (Inference Chunked)": None, "AYA-Expanse-8B (OmniGEC)": 42.80, "Gemma-3-12B-IT (MultiGEC)": 52.81, "Gemma-3-12B-IT (OmniGEC)": 49.42, "LLaMA-3-8B (MultiGEC)": None, "Gemma-2-9B (MultiGEC)": 57.89},
    {"language": "Estonian",   "corpus": "EKIL2",       "track": "fluency", "AYA-Expanse-8B (MultiGEC)": 53.51, "AYA-Expanse-8b (Inference Chunked)": None, "AYA-Expanse-8B (OmniGEC)": 56.29, "Gemma-3-12B-IT (MultiGEC)": 61.54, "Gemma-3-12B-IT (OmniGEC)": 59.84, "LLaMA-3-8B (MultiGEC)": 56.96, "Gemma-2-9B (MultiGEC)": 68.23},
    {"language": "German",     "corpus": "Merlin",      "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 78.63, "AYA-Expanse-8b (Inference Chunked)": 78.47, "AYA-Expanse-8B (OmniGEC)": 78.22, "Gemma-3-12B-IT (MultiGEC)": 71.14, "Gemma-3-12B-IT (OmniGEC)": 74.11, "LLaMA-3-8B (MultiGEC)": 0.05, "Gemma-2-9B (MultiGEC)": 81.13},
    {"language": "Greek",      "corpus": "GLCII",       "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 57.12, "AYA-Expanse-8b (Inference Chunked)": 57.12, "AYA-Expanse-8B (OmniGEC)": 56.03, "Gemma-3-12B-IT (MultiGEC)": 52.35, "Gemma-3-12B-IT (OmniGEC)": 52.67, "LLaMA-3-8B (MultiGEC)": 51.49, "Gemma-2-9B (MultiGEC)": 56.84},
    {"language": "Icelandic",  "corpus": "IceEC",       "track": "fluency", "AYA-Expanse-8B (MultiGEC)": 46.21, "AYA-Expanse-8b (Inference Chunked)": None, "AYA-Expanse-8B (OmniGEC)": 38.95, "Gemma-3-12B-IT (MultiGEC)": 29.14, "Gemma-3-12B-IT (OmniGEC)": 30.41, "LLaMA-3-8B (MultiGEC)": 83.92, "Gemma-2-9B (MultiGEC)": 85.09},
    {"language": "Icelandic",  "corpus": "IceL2EC",     "track": "fluency", "AYA-Expanse-8B (MultiGEC)": 29.98, "AYA-Expanse-8b (Inference Chunked)": None, "AYA-Expanse-8B (OmniGEC)": 31.12, "Gemma-3-12B-IT (MultiGEC)": 25.80, "Gemma-3-12B-IT (OmniGEC)": 32.18, "LLaMA-3-8B (MultiGEC)": 39.79, "Gemma-2-9B (MultiGEC)": 43.62},
    {"language": "Italian",    "corpus": "Merlin",      "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 77.51, "AYA-Expanse-8b (Inference Chunked)": 77.49, "AYA-Expanse-8B (OmniGEC)": 77.83, "Gemma-3-12B-IT (MultiGEC)": 69.90, "Gemma-3-12B-IT (OmniGEC)": 73.29, "LLaMA-3-8B (MultiGEC)": 69.96, "Gemma-2-9B (MultiGEC)": 81.89},
    {"language": "Latvian",    "corpus": "LaVA",        "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 72.29, "AYA-Expanse-8b (Inference Chunked)": 69.14, "AYA-Expanse-8B (OmniGEC)": 71.71, "Gemma-3-12B-IT (MultiGEC)": 54.05, "Gemma-3-12B-IT (OmniGEC)": 80.19, "LLaMA-3-8B (MultiGEC)": 67.25, "Gemma-2-9B (MultiGEC)": 84.50},
    {"language": "Slovenian",  "corpus": "Solar-Eval",  "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 52.24, "AYA-Expanse-8b (Inference Chunked)": 53.47, "AYA-Expanse-8B (OmniGEC)": 54.22, "Gemma-3-12B-IT (MultiGEC)": 54.67, "Gemma-3-12B-IT (OmniGEC)": 61.81, "LLaMA-3-8B (MultiGEC)": 54.34, "Gemma-2-9B (MultiGEC)": 66.46},
    {"language": "Swedish",    "corpus": "SweLL_gold",  "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 55.22, "AYA-Expanse-8b (Inference Chunked)": 55.21, "AYA-Expanse-8B (OmniGEC)": 55.99, "Gemma-3-12B-IT (MultiGEC)": 62.67, "Gemma-3-12B-IT (OmniGEC)": 62.77, "LLaMA-3-8B (MultiGEC)": 59.88, "Gemma-2-9B (MultiGEC)": 69.29},
    {"language": "Ukrainian",  "corpus": "UA-GEC",      "track": "minimal", "AYA-Expanse-8B (MultiGEC)": 77.28, "AYA-Expanse-8b (Inference Chunked)": 76.73, "AYA-Expanse-8B (OmniGEC)": 76.41, "Gemma-3-12B-IT (MultiGEC)": 74.25, "Gemma-3-12B-IT (OmniGEC)": 75.11, "LLaMA-3-8B (MultiGEC)": 74.00, "Gemma-2-9B (MultiGEC)": 79.55},
    {"language": "Ukrainian",  "corpus": "UA-GEC",      "track": "fluency", "AYA-Expanse-8B (MultiGEC)": 76.51, "AYA-Expanse-8b (Inference Chunked)": None, "AYA-Expanse-8B (OmniGEC)": 75.82, "Gemma-3-12B-IT (MultiGEC)": 74.02, "Gemma-3-12B-IT (OmniGEC)": 74.15, "LLaMA-3-8B (MultiGEC)": None, "Gemma-2-9B (MultiGEC)": 79.82},
]
aya_wiki   = [68.1765, 58.3385, 54.5993, 79.2873, 78.6427,
              38.0671, 36.2561, 53.6237, 79.3157, 57.1659,
              45.1765, 29.7086, 76.8830, 73.0337, 51.5689,
              54.8923, 77.0588, 77.1005]

gemma_wiki = [66.3900, 58.2279, 53.3792, 78.7331, 77.3001,
              55.1162, 47.5609, 57.2692, 75.4722, 53.0070,
              49.6819, 35.3240, 74.7010, 81.5365, 58.3110,
              63.9115, 75.1707, 71.8771]



df = pd.DataFrame(data)
df["AYA-Expanse-8B (MultiGEC+Wiki)"]       = aya_wiki
df["Gemma-3-12B-IT (MultiGEC+Wiki)"]       = gemma_wiki
df = df.melt(
    id_vars=["language", "corpus", "track"],
    var_name="model",
    value_name="gleu"
)
df
# Out:
#       language           corpus    track                           model  \
# 0        Czech        NatWebInf  minimal       AYA-Expanse-8B (MultiGEC)
# 1        Czech           Romani  minimal       AYA-Expanse-8B (MultiGEC)
# 2        Czech         SecLearn  minimal       AYA-Expanse-8B (MultiGEC)
# 3        Czech          NatForm  minimal       AYA-Expanse-8B (MultiGEC)
# 4      English  Write & Improve  minimal       AYA-Expanse-8B (MultiGEC)
# ..         ...              ...      ...                             ...
# 157    Latvian             LaVA  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 158  Slovenian       Solar-Eval  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 159    Swedish       SweLL_gold  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 160  Ukrainian           UA-GEC  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 161  Ukrainian           UA-GEC  fluency  Gemma-3-12B-IT (MultiGEC+Wiki)
#
#         gleu
# 0    68.1200
# 1    55.8900
# 2    53.6900
# 3    79.0000
# 4    78.4800
# ...

# %%
mapping = {
    "AYA-Expanse-8B (MultiGEC)":       "AYA-Expanse-8B (MultiGEC)",
    "AYA-Expanse-8B (MultiGEC+Wiki)":  "AYA-Expanse-8B (MultiGEC+Wiki)",
    "AYA-Expanse-8B (OmniGEC)":        "AYA-Expanse-8B (MultiGEC+Wiki+Reddit)",
    "Gemma-3-12B-IT (MultiGEC)":       "Gemma-3-12B-IT (MultiGEC)",
    "Gemma-3-12B-IT (MultiGEC+Wiki)":  "Gemma-3-12B-IT (MultiGEC+Wiki)",
    "Gemma-3-12B-IT (OmniGEC)":        "Gemma-3-12B-IT (MultiGEC+Wiki+Reddit)",
}



# Option 2: assign back
df['model'] = df['model'].replace(mapping)
#df = df.loc[~df.loc[:, "model"].isin(["Gemma-2-9B (MultiGEC)", "AYA-Expanse-8b (Inference Chunked)"])]
df
# Out:
#       language           corpus    track                           model  \
# 0        Czech        NatWebInf  minimal       AYA-Expanse-8B (MultiGEC)
# 1        Czech           Romani  minimal       AYA-Expanse-8B (MultiGEC)
# 2        Czech         SecLearn  minimal       AYA-Expanse-8B (MultiGEC)
# 3        Czech          NatForm  minimal       AYA-Expanse-8B (MultiGEC)
# 4      English  Write & Improve  minimal       AYA-Expanse-8B (MultiGEC)
# ..         ...              ...      ...                             ...
# 157    Latvian             LaVA  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 158  Slovenian       Solar-Eval  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 159    Swedish       SweLL_gold  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 160  Ukrainian           UA-GEC  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 161  Ukrainian           UA-GEC  fluency  Gemma-3-12B-IT (MultiGEC+Wiki)
#
#         gleu
# 0    68.1200
# 1    55.8900
# 2    53.6900
# 3    79.0000
# 4    78.4800
# ...

# %%
df = df[~df["model"].isin(["Gemma-2-9B (MultiGEC)", "AYA-Expanse-8b (Inference Chunked)"])]
df
# Out:
#       language           corpus    track                           model  \
# 0        Czech        NatWebInf  minimal       AYA-Expanse-8B (MultiGEC)
# 1        Czech           Romani  minimal       AYA-Expanse-8B (MultiGEC)
# 2        Czech         SecLearn  minimal       AYA-Expanse-8B (MultiGEC)
# 3        Czech          NatForm  minimal       AYA-Expanse-8B (MultiGEC)
# 4      English  Write & Improve  minimal       AYA-Expanse-8B (MultiGEC)
# ..         ...              ...      ...                             ...
# 157    Latvian             LaVA  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 158  Slovenian       Solar-Eval  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 159    Swedish       SweLL_gold  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 160  Ukrainian           UA-GEC  minimal  Gemma-3-12B-IT (MultiGEC+Wiki)
# 161  Ukrainian           UA-GEC  fluency  Gemma-3-12B-IT (MultiGEC+Wiki)
#
#         gleu
# 0    68.1200
# 1    55.8900
# 2    53.6900
# 3    79.0000
# 4    78.4800
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Sample df_long creation for demo purposes
# Assuming df_long already exists
# agg = (df_long.groupby(['track','language','model'])['gleu'].mean().reset_index())

# Use the actual agg from before
agg = (
    df
    .groupby(['track', 'language', 'model'])['gleu']
    .mean()
    .reset_index()
)

# Prepare RdYlGn colormap with gray for NaNs
cmap = plt.get_cmap("RdYlGn").copy()
cmap.set_bad("lightgray")

for track in agg['track'].unique():
    sub = agg[agg['track'] == track]
    mat = sub.pivot(index='language', columns='model', values='gleu').astype(float)
    data = np.ma.masked_invalid(mat.values)

    models = mat.columns.tolist()
    # Create two-line labels
    labels = []
    for m in models:
        if "(" in m and m.endswith(")"):
            name, sep, rest = m.partition(" (")
            labels.append(f"{name}\n({rest}")
        else:
            labels.append(m)

    # Boundary index
    idx_llama = models.index("LLaMA-3-8B (MultiGEC)")
    boundary = idx_llama - 0.5

    height = 8 if track == 'minimal' else 6
    fig, ax = plt.subplots(figsize=(12, height))
    im = ax.imshow(data, aspect='auto', cmap=cmap, alpha=0.5)
    ax.axvline(boundary, color='black', linewidth=1)
    ax.grid(False)

    for side in ["top", "bottom", "left", "right"]:
        ax.spines[side].set_visible(True)    # make sure it’s shown
        ax.spines[side].set_linewidth(1)   # thickness (adjust to taste)
        ax.spines[side].set_color("black")

    ax.set_ylabel('Language')
    ax.set_xlabel('Model')
    ax.set_yticks(range(len(mat.index)))
    ax.set_yticklabels(mat.index)
    ax.set_xticks(range(len(models)))
    ax.set_xticklabels(labels, rotation=45, ha='right')

    # Annotate
    row_max = np.nanmax(mat.values, axis=1)
    for i in range(mat.shape[0]):
        for j in range(mat.shape[1]):
            val = mat.iat[i,j]
            txt = "–" if np.isnan(val) else f"{val:.2f}"
            weight = 'bold' if not np.isnan(val) and np.isclose(val, row_max[i]) else 'normal'
            ax.text(j, i, txt, ha='center', va='center', fontweight=weight, color='black')

    # Group headers under axis
    total = len(models)
    frac_our = idx_llama / total
    frac_comp = 1 - frac_our
    ax.text(frac_our/2, 1.1, 'Our Results', transform=ax.transAxes, ha='center', va='top', weight='bold')
    ax.text(frac_our + frac_comp/2, 1.1, 'MultiGEC-25 Comp.', transform=ax.transAxes, ha='center', va='top', weight='bold')

    plt.colorbar(im, ax=ax, label='GLEU')
    plt.tight_layout()
    plt.savefig(f"{track}.png", dpi=300)
    plt.show()
